# %% [markdown]
#  # No Pane, No Gain

# %% [markdown]
#  Panes are a fundamental component of Panel dashboards. Panel dashboards cannot be created without Panes. Use your knowledge of Panel panes to convert a Plotly plot to a pane object.

# %%
import plotly.express as px
import pandas as pd
import numpy as np
import panel as pn
from panel.interact import interact
from panel import widgets

pn.extension("plotly")

# %% [markdown]
#  ## Create Pane using Interact Function

# %% [markdown]
#  ### Prep & Plot the Data

# %%
def create_parallel_categories_plot(number_of_records):
    # Create dimensions
    metropolitan = ["New York City", "San Francisco", "Dallas"]
    housing_type = ["Apartment", "Home", "Commercial"]
    seasons = ["All", "Breezy", "Dry Heat"]
    prop_size = ["Large", "Medium", "Small"]

    # Create DF using dimensions and numpy random generators
    df = pd.DataFrame(
        {
            "sold": np.random.randint(999, 10000, number_of_records),
            "year": np.random.randint(2010, 2019, number_of_records),
            "metropolitan": np.random.choice(metropolitan, number_of_records),
            "housing_type": np.random.choice(housing_type, number_of_records),
            "seasons": np.random.choice(seasons, number_of_records),
            "prop_size": np.random.choice(prop_size, number_of_records),
        }
    ).sort_values(["year", "housing_type", "metropolitan", "prop_size"])

    # Create parallel categories plot
    metro_prop_sale = px.parallel_categories(
        df,
        dimensions=["housing_type", "metropolitan", "prop_size", "seasons"],
        color="year",
        color_continuous_scale=px.colors.sequential.Inferno,
        labels={
            "housing_type": "Type of Property",
            "metropolitan": "Metropolitan",
            "prop_size": "Property Size",
            "seasons": "Seasons",
        },
        width=1200,
    )

    return metro_prop_sale

# %% [markdown]
#  ### Create interact widget to dynamically change size of plotted dataset

# %%
# Use interact function to create interaction widget
interact(create_parallel_categories_plot , number_of_records=30 )
# Out:
# Column
#     [0] Column
#         [0] IntSlider(end=90, name='number_of_records', start=-30, value=30)
#     [1] Row
#         [0] Plotly(Figure, name='interactive00147')

# %% [markdown]
#  ## Create Pane using panel.pane.Plotly function

# %% [markdown]
#  ### Manually convert plot to a pane

# %%
def add_nums(x,y):
    return (x + y)

# %%
my_num = add_nums(1,2)

# %%
my_num
# Out:
# 3

# %%
# Use panel.Pane.Plotly function to convert plot to pane
pn.pane.Plotly(interact(create_parallel_categories_plot , number_of_records=30 ))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_31640/1694472287.py in <module>
#       1 # Use panel.Pane.Plotly function to convert plot to pane
# ----> 2 pn.pane.Plotly(interact(create_parallel_categories_plot , number_of_records=30 ))
#
# ~\anaconda4\envs\pyvizenv\lib\site-packages\panel\pane\plotly.py in __init__(self, object, **params)
#      68
#      69     def __init__(self, object=None, **params):
# ---> 70         super().__init__(object, **params)
#      71         self._figure = None
#      72         self._event = None
#
# ~\anaconda4\envs\pyvizenv\lib\site-packages\panel\pane\base.py in __init__(self, object, **params)
#     110         applies = self.applies(object, **(params if self._applies_kw else {}))
#     111         if (isinstance(applies, bool) and not applies) and object is not None :
# --> 112             self._type_error(object)
#     113
#     114         super().__init__(object=object, **params)
#
# ~\anaconda4\envs\pyvizenv\lib\site-packages\panel\pane\base.py in _type_error(self, object)
#     120     def _type_error(self, object):
#     121         raise ValueError("%s pane does not support objects of type '%s'." %
# --> 122                          (type(self).__name__, type(object).__name__))
#     123
#     124     def __repr__(self, depth=0):
#
# ValueError: Plotly pane does not support objects of type 'Column'.

# %% [markdown]
#  ### Check pane type

# %%
# Check the pane type using the pprint() function
